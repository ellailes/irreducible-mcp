# %%
import numpy as np
import irreducible_library as irr
import os, sys
import matplotlib.pyplot as plt
import scipy
# %matplotlib inline
# %load_ext autoreload
plt.style.use('default')
from matplotlib import rc, rcParams
from irreducible_library import relic, relic_ann, relic_plas
# Make use of TeX\ufeff
#rc('text',usetex=True)
# Change all fonts to ‘Computer Modern’
rc('font',**{'size':14, 'family':'serif','serif':['Times New Roman']})

# %%
f, axs=plt.subplots(1,2)
f.set_figwidth(8)
Tlist = np.logspace(2.5,-2.5, num=200)
ax = axs[0]
ax.loglog(Tlist, [irr.gamma_ann(10e-12,0.04,i) for i in Tlist],label='$Q=10e-12$')
ax.loglog(Tlist, [irr.gamma_ann(10e-13,0.04,i) for i in Tlist],label='$Q=10e-13$')
ax.loglog(Tlist, [irr.gamma_ann(10e-14,0.04,i) for i in Tlist],label='$Q=10e-14$')
ax.set_xlabel('$T$ [MeV]',fontsize=20)
ax.set_ylabel('$\Gamma_{ann}$',fontsize=20)
ax.set_title("$m_\chi=40$keV")
ax.set_xlim([10,0.005])
ax.legend()

ax = axs[1]
ax.loglog(Tlist, [irr.gamma_ann(10e-12,0.04,i) for i in Tlist],label='$m_\chi=40$keV')
ax.loglog(Tlist, [irr.gamma_ann(10e-12,0.004,i) for i in Tlist],label='$m_\chi=4$keV')
ax.loglog(Tlist, [irr.gamma_ann(10e-12,0.00004,i) for i in Tlist],label='$m_\chi=40$eV')
ax.set_xlabel('$T$ [MeV]',fontsize=20)
ax.set_ylabel('$\Gamma_{ann}$',fontsize=20)
ax.set_title("$Q=10e-12$keV")
ax.set_xlim([10,0.005])
ax.set_ylim([10e-100,10e-23])
ax.legend()
f.tight_layout()
plt.show()
# Out:
# [4.394151720101326e-21, 3.902049271405248e-21, 3.464360934168561e-21, 3.075125337498367e-21, 2.7290316974985606e-21, 2.4213487406331244e-21, 2.147861400726337e-21, 1.904814440916662e-21, 1.6888622445588396e-21, 1.497024101593416e-21, 1.3266443903810475e-21, 1.1753571204164715e-21, 1.0410543595730189e-21, 9.218581213671844e-22, 8.160953338737995e-22, 7.222755529909758e-22, 6.390711193090399e-22, 5.652994903793363e-22, 4.999075091550491e-22, 4.419573951887807e-22, 3.906142681807884e-22, 3.4513503400060464e-22, 3.0485848164263375e-22, 2.6919645598173796e-22, 2.3762598589759607e-22, 2.0968226053965132e-22, 1.8495235838495625e-22, 1.6306964445183014e-22, 1.4370876070197143e-22, 1.2658114339905986e-22, 1.1143100907838458e-22, 9.803175788603656e-23, 8.618274941762517e-23, 7.570641186224957e-23, 6.644565026559008e-23, 5.826152409031648e-23, 5.1031167997115674e-23, 4.464593292553582e-23, 3.9009727159955564e-23, 3.403753917373666e-23, 2.965412571820636e-23, 2.5792849938115416e-23, 2.239465533503713e-23, 1.940716225064017e-23, 1.6783874284579903e-23, 1.44834827677696e-23, 1.2469258135226122e-23, 1.0708517817305824e-23, 9.172161106146561e-24, 7.834262347944
# %%
f, axs=plt.subplots(1,2)
f.set_figwidth(8)
Tlist = np.logspace(2.5,-2.5, num=200)
ax = axs[0]
ax.loglog(Tlist, [irr.gamma_long(10e-12,0.04,i) for i in Tlist],label='$Q=10e-12$')
ax.loglog(Tlist, [irr.gamma_long(10e-13,0.04,i) for i in Tlist],label='$Q=10e-13$')
ax.loglog(Tlist, [irr.gamma_long(10e-14,0.04,i) for i in Tlist],label='$Q=10e-14$')
ax.set_xlabel('$T$ [MeV]',fontsize=20)
ax.set_ylabel('$\Gamma_{long}$',fontsize=20)
ax.set_title("$m_\chi=40$keV")
ax.set_xlim([100,0.5])
ax.legend()

ax = axs[1]
ax.loglog(Tlist, [irr.gamma_long(10e-12,0.04,i) for i in Tlist],label='$m_\chi=40$keV')
ax.loglog(Tlist, [irr.gamma_long(10e-12,0.004,i) for i in Tlist],label='$m_\chi=4$keV')
ax.loglog(Tlist, [irr.gamma_long(10e-12,0.00004,i) for i in Tlist],label='$m_\chi=40$eV')
ax.set_xlabel('$T$ [MeV]',fontsize=20)
ax.set_ylabel('$\Gamma_{long}$',fontsize=20)
ax.set_title("$Q=10e-12$keV")
ax.set_xlim([100,0.02])
ax.set_ylim([10e-50,10e-20])
ax.legend()
f.tight_layout()
plt.show()

# %%
f, axs=plt.subplots(1,2)
f.set_figwidth(8)
Tlist = np.logspace(2.5,-2.5, num=200)
ax = axs[0]
ax.loglog(Tlist, [irr.gamma_trans(10e-12,0.04,i) for i in Tlist],label='$Q=10e-12$')
ax.loglog(Tlist, [irr.gamma_trans(10e-13,0.04,i) for i in Tlist],label='$Q=10e-13$')
ax.loglog(Tlist, [irr.gamma_trans(10e-14,0.04,i) for i in Tlist],label='$Q=10e-14$')
ax.set_xlabel('$T$ [MeV]',fontsize=20)
ax.set_ylabel('$\Gamma_{trans}$',fontsize=20)
ax.set_title("$m_\chi=40$keV")
ax.set_xlim([100,0.5])
ax.legend()

ax = axs[1]
ax.loglog(Tlist, [irr.gamma_trans(10e-12,0.04,i) for i in Tlist],label='$m_\chi=40$keV')
ax.loglog(Tlist, [irr.gamma_trans(10e-12,0.004,i) for i in Tlist],label='$m_\chi=4$keV')
ax.loglog(Tlist, [irr.gamma_trans(10e-12,0.00004,i) for i in Tlist],label='$m_\chi=40$eV')
ax.set_xlabel('$T$ [MeV]',fontsize=20)
ax.set_ylabel('$\Gamma_{trans}$',fontsize=20)
ax.set_title("$Q=10e-12$keV")
ax.set_xlim([100,0.02])
ax.set_ylim([10e-50,10e-20])
ax.legend()
f.tight_layout()
plt.show()
# Out:
# /Users/ellailes/Code/Irreducible-mcp/irreducible_library.py:454: RuntimeWarning: overflow encountered in exp
#   /(3*wt*mt**2 *(np.exp(wt/T)-1))
